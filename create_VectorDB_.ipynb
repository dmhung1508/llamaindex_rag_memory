# %% [markdown]
# ### Part 1: Creating the Vector Database with ChromaDB and Hugging Face Embeddings
# **Introduction:**
# In this part, we will create a vector database using Chroma DB to store embeddings generated by Hugging Face's embedding models. This vector database will serve as the foundation for the retrieval component of our RAG system.

# %%
# All packages are in requirements.txt

# !pip install -r /content/requi.txt
# Out:
# Collecting chroma-hnswlib==0.7.3 (from -r /content/requi.txt (line 1))
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 11.8 MB/s eta 0:00:00
# Collecting chromadb==0.4.16 (from -r /content/requi.txt (line 2))
#   Downloading chromadb-0.4.16-py3-none-any.whl (496 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.1/496.1 kB 23.4 MB/s eta 0:00:00
# Collecting llama-index==0.8.64.post1 (from -r /content/requi.txt (line 3))
#   Downloading llama_index-0.8.64.post1-py3-none-any.whl (846 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.1/846.1 kB 23.6 MB/s eta 0:00:00
# Collecting llama_cpp_python==0.2.16 (from -r /content/requi.txt (line 4))
#   Downloading llama_cpp_python-0.2.16.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 17.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PyPDF2==3.0.1 (from -r /content/requi.txt (line 5))
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from chroma-hnswlib==0.7.3->-r /content/requi.txt (line 1)) (1.25.2)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (2.6.1)
# Collecting fastapi>=0.95.2 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 16.3 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.0 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading posthog-3.4.2-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 71.6 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 88.2 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 228.1 kB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.60.1)
# Collecting bcrypt>=4.0.1 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 63.7 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.4 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.16->-r /content/requi.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (2.0.27)
# Collecting aiostream<0.6.0,>=0.5.2 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading aiostream-0.5.2-py3-none-any.whl (39 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (2023.6.0)
# Collecting langchain>=0.0.303 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading langchain-0.1.9-py3-none-any.whl (816 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.6.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (3.8.1)
# Collecting openai>=1.1.0 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.5.3)
# Collecting tiktoken>=0.3.3 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 92.3 MB/s eta 0:00:00
# Collecting typing-inspect>=0.8.0 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting urllib3<2 (from llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 22.6 MB/s eta 0:00:00
# Collecting diskcache>=5.6.1 (from llama_cpp_python==0.2.16->-r /content/requi.txt (line 4))
#   Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 7.7 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading marshmallow-3.21.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.14.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.2.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (4.0.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.21 (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading langchain_community-0.0.24-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.7 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1.26 (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading langchain_core-0.1.27-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 35.7 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading langsmith-0.1.10-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (2023.12.25)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2)) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2)) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.12)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.3.0)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.62.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_proto-1.23.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 8.4 MB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-sdk>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.4.16->-r /content/requi.txt (line 2)) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.6)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (3.0.3)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.20.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.2 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 42.8 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 102.7 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.6 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (2023.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.9.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3)) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (4.9)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.1.0->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.13.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (3.17.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain>=0.0.303->llama-index==0.8.64.post1->-r /content/requi.txt (line 3))
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 21.1 MB/s eta 0:00:00
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.16->-r /content/requi.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.16->-r /content/requi.txt (line 2)) (0.5.1)
# Building wheels for collected packages: llama_cpp_python, pypika
#   Building wheel for llama_cpp_python (pyproject.toml) ... done
#   Created wheel for llama_cpp_python: filename=llama_cpp_python-0.2.16-cp310-cp310-manylinux_2_35_x86_64.whl size=1888257 sha256=1cd6c5496c83c3877965e400354812c70f94801d91ca761cb67f915c37d7cbdb
#   Stored in directory: /root/.cache/pip/wheels/5b/2d/75/aea44211650edc2984c799575c2572b6677e561dad9f969257
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=7ee2721e6298fc3f4d95bf0d556e871572304ce077343f19220666ee81d119e9
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built llama_cpp_python pypika
# Installing collected packages: pypika, monotonic, websockets, uvloop, urllib3, python-dotenv, PyPDF2, pulsar-client, overrides, orjson, opentelemetry-semantic-conventions, opentelemetry-proto, mypy-extensions, marshmallow, jsonpointer, importlib-metadata, humanfriendly, httptools, h11, diskcache, deprecated, chroma-hnswlib, bcrypt, backoff, aiostream, watchfiles, uvicorn, typing-inspect, starlette, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, llama_cpp_python, jsonpatch, httpcore, coloredlogs, tiktoken, posthog, opentelemetry-sdk, onnxruntime, langsmith, httpx, fastapi, dataclasses-json, opentelemetry-exporter-otlp-proto-grpc, openai, langchain-core, kubernetes, langchain-community, chromadb, langchain, llama-index
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# Successfully installed PyPDF2-3.0.1 aiostream-0.5.2 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.16 coloredlogs-15.0.1 dataclasses-json-0.5.14 deprecated-1.2.14 diskcache-5.6.3 fastapi-0.110.0 h11-0.14.0 httpcore-1.0.4 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 importlib-metadata-6.11.0 jsonpatch-1.33 jsonpointer-2.4 kubernetes-29.0.0 langchain-0.1.9 langchain-community-0.0.24 langchain-core-0.1.27 langsmith-0.1.10 llama-index-0.8.64.post1 llama_cpp_python-0.2.16 marshmallow-3.21.0 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.17.1 openai-1.13.3 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 orjson-3.9.15 overrides-7.7.0 posthog-3.4.2 pulsar-client-3.4.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.36.3 tiktoken-0.6.0 typing-inspect-0.9.0 urllib3-1.26.18 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
from PyPDF2 import PdfReader

# %%
CHUNK_SIZE = 350
CHUNK_OVERLAP = 15

# %% [markdown]
# #### 1. Download an example PDF from arXiv
# For this RAG example we are using the Language Models are Few-Shot Learners paper

# %% [markdown]
# #### 2. Convert the PDF to LlamaIndex Documents
# For this example we will be using the Document format.
# This allows us to include the page_content and pass our metadata which is uses for citing sources

# %%
from llama_index import Document

# %%
reader = PdfReader("/content/triet.pdf")
print(reader.pages)
# Out:
# <PyPDF2._page._VirtualList object at 0x7a127df3b2e0>

# %%
reader = PdfReader("/content/triet.pdf")
print(reader.pages)
doc = []
for idx, page in enumerate(reader.pages):
    doc.append(Document(text=page.extract_text(),
                        metadata={'source': 'Triết học PTIT', 'page': f'{idx+1}'},
                        excluded_llm_metadata_keys=['link'],
                        excluded_embed_metadata_keys=['source', 'page', 'link']))

print(f'Number of pages {len(doc)}')
# Out:
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1b1 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# <PyPDF2._page._VirtualList object at 0x7a127df3b5e0>
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1783d for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x17aae for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x15ca4 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x10e60 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x16657 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x12085 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xfdce for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x13196 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x131a7 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x173e1 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x14f1a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x14d77 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xf417 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xa0cc for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xc9aa for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1aaff for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1c1e3 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x17e99 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1b303 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1c422 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1a479 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xf83c for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x6325 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x8e7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x72cd for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x690d for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x782c for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x6707 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x19099 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x17895 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x15f04 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x145d2 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1d2b8 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1528d for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# Number of pages 167

# %% [markdown]
# #### 3. Convert Documents into LlamaIndex Nodes
# We split our documents into 'chunks' to be embedded.
# Each chunk is what LlamaIndex calls a **Node**.

# %%
from llama_index.node_parser import SimpleNodeParser

parser = SimpleNodeParser.from_defaults(include_metadata = True, chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)

nodes = parser.get_nodes_from_documents(doc)

print(f'Parsed the {len(doc)} pages into {len(nodes)} nodes')
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Parsed the 167 pages into 1567 nodes

# %%
from llama_index.schema import MetadataMode

# %%
# This prints what the LLM sees
print (nodes[50].get_content (metadata_mode=MetadataMode.LLM))
# Out:
# source: Triết học PTIT
# page: 9
#
# BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN
#
#
#
# BỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 7 cứu riêng c ho mình như mô t ả những hi ện tượng tinh th ần, phân tích ng ữ nghĩa, chú
# giải văn b ản.
# Mặc dù v ậy, cái chung trong các h ọc thuy ết triết học là nghiên c ứu những vấn đề
# chung nh ất của giới tự nhiên, c ủa xã h ội và con ngư ời, mối quan h ệ của con ngư ời,

# %%
# This prints what the embedding sees, you can see excluding source and page worked
print (nodes[50].get_content (metadata_mode=MetadataMode.EMBED))
# Out:
# BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN
#
#
#
# BỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 7 cứu riêng c ho mình như mô t ả những hi ện tượng tinh th ần, phân tích ng ữ nghĩa, chú
# giải văn b ản.
# Mặc dù v ậy, cái chung trong các h ọc thuy ết triết học là nghiên c ứu những vấn đề
# chung nh ất của giới tự nhiên, c ủa xã h ội và con ngư ời, mối quan h ệ của con ngư ời,

# %%
from llama_index import VectorStoreIndex, ServiceContext
from llama_index.vector_stores import ChromaVectorStore
from llama_index.storage.storage_context import StorageContext

# %% [markdown]
# #### Setting Device:
# If you are using a Mac or an Nvidia GPU and installed PyTorch correctly the below will use the correct device
# Otherwise it will default to using the CPU
#
# For details on how to install PyTorch for CUDA see the [Get Started page](https://pytorch.org/get-started/locally/)
# If you are not using CUDA with an Nvidia GPU you can uncomment the line below:

# %%
# Install PyTorch for Mac or Windows PC without Nvidia GPU
# !pip install torch torchvision torchaudio
# !pip install transformers

# %%
import torch
# Detect hardware acceleration device
if torch.cuda.is_available():
    device = 'cuda'
elif torch.backends.mps.is_available():
    device = 'mps'
else:
    device = 'cpu'

print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# **Load Embedding Model:**
# A good place to start when choosing and embedding model is the [MTEB English Leaderboard](https://huggingface.co/BAAI/bge-small-en)
#
# At time of writing, the [BAAI/bge-small-en-v1.5'model](https://huggingface.co/spaces/mteb/leaderboard) is the best small model according to the leaderboard

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
embed_model_name = 'bkai-foundation-models/vietnamese-cross-encoder'
# Import embedding model from HuggingFace
embed_model = HuggingFaceEmbedding(
    model_name=embed_model_name,
    device = device,
    normalize='True',
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/814 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at bkai-foundation-models/vietnamese-cross-encoder and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %% [markdown]
# ### 4. Create and store the Vector DB
# * This will use the bge-small-en embeddings model to embed our chunked text into vectors
# * Then save those vectors into a ChromaDB named "RAG_VectorDB"
#
# **Note**: If a DB with that name already exists, it will append, otherwise it creates it

# %%
import chromadb

db = chromadb.PersistentClient(path='./RAG_VectorDB')

collection_metadata = {
    'embedding_used':embed_model_name,
    'Included Papers':"Triết học PTIT"}
chroma_collection = db.get_or_create_collection('trietptit', metadata=collection_metadata)

vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

storage_context = StorageContext.from_defaults(vector_store=vector_store)

service_context = ServiceContext.from_defaults(embed_model=embed_model,
                                                llm = None, # We will set the LLM when we open the DB
                                                chunk_size=CHUNK_SIZE,
                                                chunk_overlap=CHUNK_OVERLAP
                                                )

vector_store_index = VectorStoreIndex(nodes=nodes,
                                    storage_context=storage_context,
                                    service_context=service_context,
                                    show_progress=True)

print('Completed')
# Out:
# LLM is explicitly disabled. Using MockLLM.
# Generating embeddings:   0%|          | 0/1567 [00:00<?, ?it/s]
# Completed

# %%
# Import thư viện shutil để sử dụng hàm make_archive
import shutil

# Đường dẫn đến thư mục bạn muốn nén
thu_muc = "/content/RAG_VectorDB"

# Đường dẫn đến file zip sau khi nén
file_nen = "/content/index"

# Sử dụng hàm make_archive từ thư viện shutil để nén thư mục
shutil.make_archive(file_nen, 'zip', thu_muc)
# Out:
# '/content/index.zip'
